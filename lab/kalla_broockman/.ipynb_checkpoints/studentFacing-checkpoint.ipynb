# %% [markdown]
# # Lab #Number: Broockman and Kalla

# %% [markdown]
# In this lab, we'll be replicating the findings of "Durably Reducing Transphobia: A Field Experiment on Door-to-Door Canvassing" David Broockman and Joshua Kalla (Joshua Kalla is a UC Berkeley Poli Sci Professor). The original paper can be found [here](http://statmodeling.stat.columbia.edu/wp-content/uploads/2016/04/transphobia-and-canvassing.pdf). Originally, the paper's computation and visualization was done in a programming language called ```R```. The link to the original code can be found [here](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/WKR39N). Instead of ```R```, we'll be using ```seaborn``` and ```matplotlib``` instead.

# %% [markdown]
# Existing research depicts intergroup prejudices as deeply ingrained, requiring intense intervention to lastingly reduce. Here, we show that a single approximately 10-minute conversation encouraging actively taking the perspective of others can markedly reduce prejudice for at least 3 months. A randomized trial found that these conversations substantially reduced transphobia, with decreases greater than Americans’ average decrease in homophobia from 1998 to 2012. These effects persisted for 3 months, and both transgender and nontransgender canvassers were effective. The interventio nalso increased support for a nondiscrimination law, even after exposing voters to counterarguments

# %% [markdown]
# Run the next cell to import the packages we'll be using.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)
plt.rcParams['figure.dpi'] = 150
sns.set()

# %% [markdown]
# ## ```seaborn``` and ```matplotlib```

# %% [markdown]
# [```seaborn```](https://seaborn.pydata.org/) is a powerful visualization package built upon another package called [```matplotlib```](https://matplotlib.org/). Let's take a look at these two packages in action!
#
# Run the next cell to read in a demo dataframe.

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# To create a simple scatterplot using ```seaborn```, we'll use the ```sns.scatterplot``` function.
#
# This function uses the following arguments:
#  * ```data```: The dataframe that you are using in this plot
#  * ```x```: The column of the dataframe to use as the x coordinates of the points
#  * ```y```: The column of the dataframe to use as the y coordinates of the points
#  * ```s```: The size of the data points
#
# Make sure that you put the name of each column in quotes. 'Single quotes' or "Double quotes" are both okay.

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", s=100)

# %% [markdown]
# Pretty cool, right? What about the ```<matplotlib.axes._subplots.AxesSubplot at 0x195892e6188>``` at the top of the graph? To get rid of the extra text, add in a ```;``` to the last line of code. Run the next cell to see how this works.

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip");

# %% [markdown]
# What if we want to see which data points in out scatterplot correspond to which meal? You can set the ```hue``` argument to variable ```"time``` to have the "Lunch" data points be set to blue and the "Dinner" data points to be set to orange.

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time");

# %% [markdown]
# Let's try adding in a helpful title, x-axis label, and y-axis label.
#
# **Notice that to add a title, x label, and y label, use ```plt.``` instead of ```sns.```**

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
plt.title("Lunch Tips vs Dinner Tips")
plt.ylabel("Tip Amount, in Dollars")
plt.xlabel("Total Bill Amount, in Dollars");

# %% [markdown]
# What if you want to add other elements to the plot? Let's add some text, lines, and a legend to the plot.
#
# Here are the arguments of the functions in use below:
#  * ```plt.plot```:
#   * [10, 10]: The first list is the starting and ending **x value**. Since we want a vertical line, these numbers should be the same
#   * [2, 10]: The second list is the starting and ending **y value**. In this example, we want the line to start at y = 2 and end at y = 10
#   * color: This allows us to select what color we would like to have the line be
#   * linestyle: This allows us to select if we want a solid line, dashed line, or other type of line
#  * ```plt.text```:
#   * s: This is the text you would like to have on the plot
#   * x: This is the x value where the text should start
#   * y: This is the y value where the text should start
#   * rotation: This value rotates the text

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")

plt.plot([10,10], [2,10], color = "black", linestyle = "dashed")
plt.text(s = "$10", x = 8, y = 6)
plt.text(s = "$10", x = 8, y = 8, rotation = 90)

plt.title("Lunch Tips vs Dinner Tips")
plt.ylabel("Tip Amount, in Dollars")
plt.xlabel("Total Bill Amount, in Dollars");

# %% [markdown]
# ### Now it's your turn!

# %% [markdown]
# Read in the data to get started.

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Your goal is to recreate the following plot:
#
# Your plot needs to have the following:
#  * A scatterplot with ```sepal_length``` on the x axis and ```petal_length``` on the y axis
#  * The hue should be set to ```species```
#  * A black dashed vertical line at x = 6 that goes from y = 1 to y = 8
#  * The word "setosa" at x = 4.5 and y = 2
#  * The word "versicolor" at x = 6.5 and y = 3. This word should be rotated 90 degrees.
#  * The title should be "Sepal Length vs Petal Length"
#  * The x axis label should be "Sepal Length"
#  * The y axis label should be "Petal Length"
#
# If you are having trouble, try looking at the examples above! Also make sure you are using ```plt.``` and ```sns.``` for the appropriate functions.
#
# ![irisDemo](irisDemo.png)

# %%
# Student code here

# %%
sns.scatterplot(data=iris, x="sepal_length", y="petal_length", hue="species")

plt.plot([6,6], [1,8], color = "black", linestyle = "dashed")
plt.text(s = "setosa", x = 4.5, y = 2)
plt.text(s = "versicolor", x = 6.5, y = 3, rotation = 90)

plt.title("Sepal Length vs Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length");

# %% [markdown]
# ## Kalla and Broockman Replication

# %% [markdown]
# Now that we have an understanding of how to use ```seaborn``` and ```matplotlib```, let's use these packages to visualize the findings of this paper.

# %% [markdown]
# Start by reading in the data.

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                                  Canvasser  days  point.estimate  se.low  \
# 0                                      All     1           0.292   0.220
# 1                                      All    19           0.238   0.159
# 2                                      All    40           0.352   0.278
# 3                                      All    82           0.345   0.267
# 4   Transgender/Gender Non-Conforming Only     5           0.453   0.344
# 5                     Non-Transgender Only     3           0.191   0.097
# 6   Transgender/Gender Non-Conforming Only    23           0.300   0.172
# 7                     Non-Transgender Only    21           0.191   0.093
# 8   Transgender/Gender Non-Conforming Only    44           0.364   0.250
# 9                     Non-Transgender Only    42           0.321   0.228
# 10  Transgender/Gender Non-Conforming Only    86           0.427   0.292
# 11                    Non-Transgender Only    84           0.324   0.220
#
# ...

# %% [markdown]
# To prepare the data for plotting, let's select pairs of data and put them into lists.
#
# The following cell does the following:
#  * ```df[["se.low","se.high"]]```: Selects the ```se.low``` and ```se.high``` columns from the ```df``` dataframe
#  * ```.values```: Gets the values for each row
#  * ```.tolist()```: Puts the values into a list
#  * ```df["se"]```: Creates a new column called ```se```

# %%
df["se"] = df[["se.low","se.high"]].values.tolist()
df["ci"] = df[["ci.low","ci.high"]].values.tolist()
df.head()
# Out:
#                                 Canvasser  days  point.estimate  se.low  \
# 0                                     All     1           0.292   0.220
# 1                                     All    19           0.238   0.159
# 2                                     All    40           0.352   0.278
# 3                                     All    82           0.345   0.267
# 4  Transgender/Gender Non-Conforming Only     5           0.453   0.344
#
#    se.high   ci.low  ci.high              se                  ci
# 0    0.364  0.15088  0.43312   [0.22, 0.364]  [0.15088, 0.43312]
# 1    0.317  0.08316  0.39284  [0.159, 0.317]  [0.08316, 0.39284]
# 2    0.426  0.20696  0.49704  [0.278, 0.426]  [0.20696, 0.49704]
# 3    0.423  0.19212  0.49788  [0.267, 0.423]  [0.19212, 0.49788]
# 4    0.562  0.23936  0.66664  [0.344, 0.562]  [0.23936, 0.66664]

# %% [markdown]
# Now it's time to create the plot from the paper.
#
# ![final](final.png)
#
# Your plot needs to have the following:
#  * A scatterplot with ```days``` as the x axis and ```point.estimate``` as the y axis using the ```df``` dataframe
#  * The hue should be the ```Canvasser``` column
#  * The size of the data points should be 100
#  * The label for the x axis should be "Days After Canvassing Treatment"
#  * The label for the y axis should be "Effect on Transgender Tolerance, in Standard Deviations"
#  * The title should be "Difference Between Treatment and Placebo"
#  * There should be a black dashed line at x = 0 and should go from y = 0 to y = 1
#  * There should be the phrase "Canvassing Treatment" at x = -1.5 and y = 0.3. This texted should be rotated 90 degrees
#  * There should be the following phrases at the following locations:
#    * "+3 Days" at x = 1, y = - 0.04
#    * "+3 Weeks" at x = 18, y = - 0.04
#    * "+6 Weeks" at x = 39, y = - 0.04
#    * "+3 Months" at x = 81, y = - 0.04

# %%
# Replace the ... with your code to create a scatterplot

...

# Replace the ... with code to create a x label

...

# Replace the ... with code to create a y label

...

# Replace the ... with code to add a title

...

# Replace the ... with code to add in a vertical line

...

# Replace the ... with code to add in the text

...
...
...
...

# Do not modify the code below this line

for _, k in df.iterrows(): # Adds in the CI and SD lines
    if k["Canvasser"] == "All":
        plt.plot([k["days"], k["days"]], k["se"], color="#4C72B0", linewidth = 3)
        plt.plot([k["days"], k["days"]], k["ci"], color="#4C72B0", linewidth = 1)
    elif k["Canvasser"] == "Non-Transgender Only":
        plt.plot([k["days"], k["days"]], k["se"], color="#54A867", linewidth = 3)
        plt.plot([k["days"], k["days"]], k["ci"], color="#54A867", linewidth = 1)
    else:
        plt.plot([k["days"], k["days"]], k["se"], color="#DD8452", linewidth = 3)
        plt.plot([k["days"], k["days"]], k["ci"], color="#DD8452", linewidth = 1)

# %%
sns.scatterplot(x="days", y="point.estimate", data=df, hue="Canvasser", s=100)

plt.xlabel("Days After Canvassing Treatment")
plt.ylabel("Effect on Transgender Tolerance, in Standard Deviations")
plt.title("Difference Between Treatment and Placebo")
plt.plot([0,0],[0,1], color="black", linestyle="dashed")


plt.text(s="Canvassing Treatment", x=-1.5, y =0.3, rotation = 90)
plt.text(s="+3 Days", x=1, y =-0.04)
plt.text(s="+3 Weeks", x=18, y =-0.04)
plt.text(s="+6 Weeks", x=39, y =-0.04)
plt.text(s="+3 Months", x=81, y =-0.04)

for _, k in df.iterrows():
    if k["Canvasser"] == "All":
        plt.plot([k["days"], k["days"]], k["se"], color="#4C72B0", linewidth = 3)
        plt.plot([k["days"], k["days"]], k["ci"], color="#4C72B0", linewidth = 1)
    elif k["Canvasser"] == "Non-Transgender Only":
        plt.plot([k["days"], k["days"]], k["se"], color="#54A867", linewidth = 3)
        plt.plot([k["days"], k["days"]], k["ci"], color="#54A867", linewidth = 1)
    else:
        plt.plot([k["days"], k["days"]], k["se"], color="#DD8452", linewidth = 3)
        plt.plot([k["days"], k["days"]], k["ci"], color="#DD8452", linewidth = 1)

# %% [markdown]
# So what did we just make? The 95% confidence intervals surround point estimates; the thicker lines represent one standard error. Both transgender and nontransgender canvassers produced large and lasting increases in tolerance.
