# %%
import pandas as pd
import numpy as np
from scipy import stats

import statsmodels.formula.api as smf

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Bring in the main analysis dataset
full = pd.read_stata("data/hall_thompson_replication_files/rd_analysis_hs.dta")
full
# Out:
#     state dist  dem    year  turnout_dem_strong  low_info_votes1  \
# 0      AK  1.0  1.0  2008.0            0.777778              0.0
# 1      AL  7.0  1.0  2006.0            0.500000              0.0
# 2      AL  2.0  0.0  2008.0            0.600000              1.0
# 3      AL  5.0  1.0  2010.0            0.684211              4.0
# 4      AL  7.0  1.0  2010.0            0.652174              3.0
# ..    ...  ...  ...     ...                 ...              ...
# 453    WV  2.0  1.0  2006.0            0.000000              0.0
# 454    WV  1.0  1.0  2010.0            0.900000             12.0
# 455    WV  1.0  0.0  2010.0            0.900000             12.0
# 456    WV  2.0  1.0  2014.0            0.368421              0.0
# 457    WY  1.0  0.0  2008.0            1.000000              1.0
#
#      high_info_votes1  low_info_n1  high_info_n1  turnout_dem_nvstrong  ...  \
# 0                 7.0          1.0           8.0              0.800000  ...
# ...

# %%
cd_demo_2015 = pd.read_csv("data/cd_demo_2015.csv", thousands=',')
cd_demo_2015
# Out:
#      District      State  Hispanic   White   Black  AmericanIndian  Asian  \
# 0           1    Alabama     21301  459077  198856            7576   8928
# 1           2    Alabama     20532  427396  216982            1696   6608
# 2           3    Alabama     21104  479091  176836            1627  10658
# 3           4    Alabama     43398  574436   48879            2623   2811
# 4           5    Alabama     35846  516031  123324            3320  11638
# ..        ...        ...       ...     ...     ...             ...    ...
# 430         5  Wisconsin     42077  632379   16285            1377  18218
# 431         6  Wisconsin     31886  636416   11615            3037  17993
# 432         7  Wisconsin     15857  650963    4566           13471  11613
# 433         8  Wisconsin     36678  634248    8951           17141  16634
# 434         1    Wyoming     57845  492659    4704           12140   4885
#
#      PacificIslander  Other  Multiple races   Total
# ...

# %%
cd_demo_2015 = cd_demo_2015.rename({"District":"dist", "State":"state"}, axis=1)

# %%
cd_demo_2015
# Out:
#      dist      state  Hispanic   White   Black  AmericanIndian  Asian  \
# 0       1    Alabama     21301  459077  198856            7576   8928
# 1       2    Alabama     20532  427396  216982            1696   6608
# 2       3    Alabama     21104  479091  176836            1627  10658
# 3       4    Alabama     43398  574436   48879            2623   2811
# 4       5    Alabama     35846  516031  123324            3320  11638
# ..    ...        ...       ...     ...     ...             ...    ...
# 430     5  Wisconsin     42077  632379   16285            1377  18218
# 431     6  Wisconsin     31886  636416   11615            3037  17993
# 432     7  Wisconsin     15857  650963    4566           13471  11613
# 433     8  Wisconsin     36678  634248    8951           17141  16634
# 434     1    Wyoming     57845  492659    4704           12140   4885
#
#      PacificIslander  Other  Multiple races   Total
# 0                  0   2145            8419  706302
# ...

# %%
#full['dist'] = full.dist.astype(int)

# %%
crosswalk = pd.read_csv("data/statecrosswalk.csv")
crosswalk
# Out:
#                    State  Abbrev Code
# 0                Alabama    Ala.   AL
# 1                 Alaska  Alaska   AK
# 2                Arizona   Ariz.   AZ
# 3               Arkansas    Ark.   AR
# 4             California  Calif.   CA
# 5               Colorado   Colo.   CO
# 6            Connecticut   Conn.   CT
# 7               Delaware    Del.   DE
# 8   District of Columbia    D.C.   DC
# 9                Florida    Fla.   FL
# 10               Georgia     Ga.   GA
# 11                Hawaii  Hawaii   HI
# 12                 Idaho   Idaho   ID
# 13              Illinois    Ill.   IL
# 14               Indiana    Ind.   IN
# 15                  Iowa    Iowa   IA
# 16                Kansas   Kans.   KS
# 17              Kentucky     Ky.   KY
# 18             Louisiana     La.   LA
# 19                 Maine   Maine   ME
# 20              Maryland     Md.   MD
# 21         Massachusetts   Mass.   MA
# 22              Michigan   Mich.   MI
# 23             Minnesota   Minn.   MN
# ...

# %%
cd_demo_2015 = cd_demo_2015.rename({"state":"State"}, axis=1)

# %%
cd_demo_2015 = pd.merge(cd_demo_2015, crosswalk, on="State", how="left")

# %%
full = full.rename({"state": "Code"}, axis=1)

# %%
full.columns
# Out:
# Index(['Code', 'dist', 'dem', 'year', 'turnout_dem_strong', 'low_info_votes1',
#        'high_info_votes1', 'low_info_n1', 'high_info_n1',
#        'turnout_dem_nvstrong',
#        ...
#        're', 'g', 'pv', 'two_party_total', 'lag_pv', 'catalist_share',
#        'no_party_id', 'gov_elec', 'senate_elec', 'mindonors'],
#       dtype='object', length=151)

# %%
full_demo = pd.merge(full, cd_demo_2015, on=["dist", "Code"], how="left")
full_demo
# Out:
#     Code  dist  dem    year  turnout_dem_strong  low_info_votes1  \
# 0     AK   1.0  1.0  2008.0            0.777778              0.0
# 1     AL   7.0  1.0  2006.0            0.500000              0.0
# 2     AL   2.0  0.0  2008.0            0.600000              1.0
# 3     AL   5.0  1.0  2010.0            0.684211              4.0
# 4     AL   7.0  1.0  2010.0            0.652174              3.0
# ..   ...   ...  ...     ...                 ...              ...
# 453   WV   2.0  1.0  2006.0            0.000000              0.0
# 454   WV   1.0  1.0  2010.0            0.900000             12.0
# 455   WV   1.0  0.0  2010.0            0.900000             12.0
# 456   WV   2.0  1.0  2014.0            0.368421              0.0
# 457   WY   1.0  0.0  2008.0            1.000000              1.0
#
#      high_info_votes1  low_info_n1  high_info_n1  turnout_dem_nvstrong  ...  \
# 0                 7.0          1.0           8.0              0.800000  ...
# ...

# %%
np.sum(full_demo['Hispanic'].isna())
# Out:
# 9

# %%
full_demo["nonwhite"] = 1-full_demo["White"]/full_demo["Total"]
full_demo["nonwhite"].hist()
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='nonwhite', y='rv', data=full_demo)
# Out:
# <AxesSubplot:xlabel='nonwhite', ylabel='rv'>

# %%
mc_data = pd.read_csv("data/allCongressDataPublishV2.csv")
mc_data
# Out:
#      state stateDist  abroadPrcnt  recentArrivalPrcnt  totalPopBirthPlace  \
# 0       AK      AK.0          NaN           54.541518            588358.0
# 1       AL      AL.3          NaN           20.234837            555795.0
# 2       AL      AL.2          NaN           24.197693            530286.0
# 3       AL      AL.1          NaN           15.405078            543377.0
# 4       AL      AL.7          NaN           16.687447            541494.0
# ...    ...       ...          ...                 ...                 ...
# 9408    AS      AS.0          NaN                 NaN                 NaN
# 9409    MP      MP.0          NaN                 NaN                 NaN
# 9410   NaN      SD.0     0.697023           23.930870            690768.0
# 9411   NaN      SD.0     0.697023           23.930870            690768.0
# 9412   NaN      SD.0     0.697023           23.930870            690768.0
#
#       prcntForeignBorn  prcntExAliens  totalHouseholds   under10k    over10k  \
# ...

# %%
mc_data.shape
# Out:
# (9413, 76)

# %%
mc_data.drop_duplicates(subset=["state", "cd", "congNum"])
# Out:
# (9301, 76)

# %%
mc_data.state.value_counts()
# Out:
# CA    1040
# NY     708
# TX     612
# PA     466
# IL     451
# FL     442
# OH     428
# MI     360
# NJ     293
# NC     252
# GA     238
# MA     229
# VA     227
# IN     212
# MO     195
# TN     187
# WI     185
# WA     177
# MD     171
# MN     169
# LA     166
# AL     148
# KY     140
# SC     128
# CO     127
# AZ     126
# OK     123
# CT     122
# IA     114
# MS     104
# OR     102
# KS      95
# AR      85
# WV      74
# NE      63
# NM      60
# UT      59
# NV      45
# HI      45
# ID      42
# ME      42
# RI      42
# NH      42
# MT      31
# SD      27
# PR      22
# WY      22
# VT      21
# AK      21
# VI      21
# ND      21
# GU      21
# DE      21
# DC      21
# AS      17
# MP       3
# Name: state, dtype: int64

# %%
mc_data.columns
# Out:
# Index(['state', 'stateDist', 'abroadPrcnt', 'recentArrivalPrcnt',
#        'totalPopBirthPlace', 'prcntForeignBorn', 'prcntExAliens',
#        'totalHouseholds', 'under10k', 'over10k', 'over15k', 'over25k',
#        'over35k', 'over50k', 'over75k', 'over100k', 'over150k', 'over200k',
#        'meanIncome', 'medianIncome', 'totalEmploymentPop', 'prcntUnemp',
#        'prcntNotEmploy', 'prcntBA', 'prcntHS', 'totalPopRaceFile',
#        'prcntAsian', 'prcntBlack', 'prcntBlackNotHisp', 'prcntHisp',
#        'prcntMulti', 'prcntWhite', 'prcntWhiteAll', 'prcntNotHisp', 'prcntOld',
#        'medianAge', 'gini', 'sponID', 'icpsr', 'district', 'lastName',
#        'firstName', 'middleName', 'age', 'gender', 'party', 'numberTerms',
#        'daysServed', 'fracServed', 'cd', 'statenm', 'dwnom1', 'dwnom2',
#        'comPower', 'chair', 'rank', 'comName', 'numCom', 'rankChair', 'black',
#        'hispanic', 'numSpon', 'numCosp', 'numPassH', 'numEnact', 'passPrcnt',
# ...

# %%
mc_data.cd
# Out:
# 0       1.0
# 1       3.0
# 2       2.0
# 3       1.0
# 4       7.0
#        ...
# 9408    NaN
# 9409    NaN
# 9410    NaN
# 9411    NaN
# 9412    NaN
# Name: cd, Length: 9413, dtype: float64

# %%
full.columns
# Out:
# Index(['Code', 'dist', 'dem', 'year', 'turnout_dem_strong', 'low_info_votes1',
#        'high_info_votes1', 'low_info_n1', 'high_info_n1',
#        'turnout_dem_nvstrong',
#        ...
#        're', 'g', 'pv', 'two_party_total', 'lag_pv', 'catalist_share',
#        'no_party_id', 'gov_elec', 'senate_elec', 'mindonors'],
#       dtype='object', length=151)

# %%
full.Code + "." + full.dist.astype(int).astype(str)
# Out:
# 0      AK.1
# 1      AL.7
# 2      AL.2
# 3      AL.5
# 4      AL.7
#        ...
# 453    WV.2
# 454    WV.1
# 455    WV.1
# 456    WV.2
# 457    WY.1
# Length: 458, dtype: object

# %%
mc_data.cd.value_counts()
# Out:
# 1.0     1072
# 2.0      919
# 3.0      777
# 4.0      712
# 5.0      657
# 6.0      577
# 7.0      490
# 8.0      426
# 9.0      362
# 10.0     296
# 11.0     249
# 12.0     214
# 13.0     204
# 14.0     182
# 15.0     174
# 16.0     157
# 18.0     154
# 17.0     152
# 19.0     142
# 20.0     114
# 21.0     111
# 22.0     101
# 23.0      95
# 24.0      79
# 25.0      69
# 27.0      59
# 26.0      59
# 29.0      53
# 28.0      52
# 30.0      48
# 31.0      43
# 32.0      37
# 33.0      32
# 34.0      32
# 36.0      28
# 37.0      28
# 35.0      27
# 39.0      27
# 38.0      26
# 42.0      22
# 43.0      21
# 41.0      21
# 40.0      21
# 44.0      17
# 45.0      16
# 48.0      12
# 50.0      12
# 46.0      11
# 47.0      11
# 52.0      11
# 49.0      11
# 51.0      11
# 53.0       6
# Name: cd, dtype: int64

# %%
mc_data = mc_data.rename({"state":"Code", "cd":"Dist"}, axis=1)

# %%
1786 +2*112
# Out:
# 2010

# %%
mc_data["year"] = mc_data.congNum*2 + 1786

# %%
mc_data.columns
# Out:
# Index(['Code', 'stateDist', 'abroadPrcnt', 'recentArrivalPrcnt',
#        'totalPopBirthPlace', 'prcntForeignBorn', 'prcntExAliens',
#        'totalHouseholds', 'under10k', 'over10k', 'over15k', 'over25k',
#        'over35k', 'over50k', 'over75k', 'over100k', 'over150k', 'over200k',
#        'meanIncome', 'medianIncome', 'totalEmploymentPop', 'prcntUnemp',
#        'prcntNotEmploy', 'prcntBA', 'prcntHS', 'totalPopRaceFile',
#        'prcntAsian', 'prcntBlack', 'prcntBlackNotHisp', 'prcntHisp',
#        'prcntMulti', 'prcntWhite', 'prcntWhiteAll', 'prcntNotHisp', 'prcntOld',
#        'medianAge', 'gini', 'sponID', 'icpsr', 'district', 'lastName',
#        'firstName', 'middleName', 'age', 'gender', 'party', 'numberTerms',
#        'daysServed', 'fracServed', 'Dist', 'statenm', 'dwnom1', 'dwnom2',
#        'comPower', 'chair', 'rank', 'comName', 'numCom', 'rankChair', 'black',
#        'hispanic', 'numSpon', 'numCosp', 'numPassH', 'numEnact', 'passPrcnt',
# ...

# %%
full = full.rename({"dist":"Dist"}, axis=1)
full.shape
# Out:
# (458, 151)

# %%
full_more = pd.merge(full, mc_data, on=["Code", "Dist", "year"], how="inner")
full_more.shape
# Out:
# (426, 226)

# %%
full_more
# Out:
#     Code  Dist  dem    year  turnout_dem_strong  low_info_votes1  \
# 0     AK   1.0  1.0  2008.0            0.777778              0.0
# 1     AL   7.0  1.0  2006.0            0.500000              0.0
# 2     AL   2.0  0.0  2008.0            0.600000              1.0
# 3     AL   5.0  1.0  2010.0            0.684211              4.0
# 4     AL   7.0  1.0  2010.0            0.652174              3.0
# ..   ...   ...  ...     ...                 ...              ...
# 421   WI   2.0  1.0  2012.0            0.760870              4.0
# 422   WV   2.0  1.0  2006.0            0.000000              0.0
# 423   WV   1.0  1.0  2010.0            0.900000             12.0
# 424   WV   1.0  0.0  2010.0            0.900000             12.0
# 425   WY   1.0  0.0  2008.0            1.000000              1.0
#
#      high_info_votes1  low_info_n1  high_info_n1  turnout_dem_nvstrong  ...  \
# 0                 7.0          1.0           8.0              0.800000  ...
# ...

# %%
(mc_data.Code + mc_data.Dist.astype(str) + mc_data.year.astype(str)).value_counts()
# Out:
# IN3.02008.0     2
# LA7.01994.0     2
# HI1.01984.0     2
# SC2.02000.0     2
# AL1.02012.0     2
#                ..
# AZ1.01986.0     1
# CA1.01986.0     1
# CA10.01986.0    1
# CA11.01986.0    1
# MPnan2012.0     1
# Length: 9295, dtype: int64

# %%
dupe_ex = mc_data[mc_data.Code + mc_data.Dist.astype(str) + mc_data.year.astype(str)=="IN3.02010.0"]
dupe_ex
# Out:
#      Code stateDist  abroadPrcnt  recentArrivalPrcnt  totalPopBirthPlace  \
# 8665   IN      IN.3          0.3                 4.1            720944.0
#
#       prcntForeignBorn  prcntExAliens  totalHouseholds  under10k  over10k  \
# 8665               4.8           37.2         272593.0       5.7     94.3
#
#       ...  demSeats  repSeats  otherSeats  cookLeanDem       ses    sesNorm  \
# 8665  ...     193.0     242.0         0.0        -14.0  0.090049  34.225696
#
#          full   region    Year    year
# 8665  Indiana  midwest  2012.0  2010.0
#
# [1 rows x 78 columns]

# %%
mc_nodupe = mc_data.drop_duplicates(subset=["Code", "Dist", "year"])
mc_nodupe.shape
# Out:
# (9301, 78)

# %%
mc_data.shape
# Out:
# (9413, 78)

# %%
full_more = pd.merge(full, mc_nodupe, on=["Code", "Dist", "year"], how="inner")
full_more.shape
# Out:
# (422, 226)
